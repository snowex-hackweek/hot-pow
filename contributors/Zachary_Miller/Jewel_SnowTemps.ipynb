# %% [markdown]
# # Grabbing Jewel's SnowPit Data

# %% [markdown]
# 1. Grab pit and format correctly to align with SnowEx database
# 2. Loop through folder of .csv's and create correct temperature profiles
# 3. Merge all profiles into one "dictionary"??? geopandas magic dataframe?

# %% [markdown]
# GoogleDrive PitDataTemperatures Folder: https://drive.google.com/drive/folders/1SFyBKULqiRLi52yiKO5mxRn5Icsp83Lm?usp=sharing
#
# Test Blob (single temp profile .csv): 1DufHRYtWqxQUFrfqdFx1FViFbaTCkmAV

# %%
# set up and select a pit to work with
import pandas as pd
df = pd.read_csv('https://drive.google.com/uc?export=download&id=1DufHRYtWqxQUFrfqdFx1FViFbaTCkmAV', header=None)
df
# Out:
#              0                                                  1      2
# 0    Location:                                        County Line    NaN
# 1        Type:                                               Open    NaN
# 2     Easting:                                             756905    NaN
# 3    Northing:                                            4324353    NaN
# 4    Surveyor:                                            J. Lund    NaN
# 5        Time:                                       3/12/20 9:58    NaN
# 6   Time Type:                                                 AM    NaN
# 7    Air Temp:                                               -2.8    NaN
# 8          Hs:                                                111    NaN
# 9      Ground:               Rough ground, no info on vegetation.    NaN
# 10      Notes:                            Temperature 9:58-10:10.    NaN
# 11         Wx:  Calm, mostly cloudy, but sun still shining (th...    NaN
# 12         NaN                                                NaN    NaN
# 13          Hs                                        Temperature  Notes
# 14         110                                               -4.4    NaN
# 15         100                                               -3.5    NaN
# 16          90                                               -3.2    NaN
# 17          80                                               -3.1    NaN
# 18          70                                               -3.1    NaN
# 19          60                                                 -3    NaN
# 20          50                                               -2.8    NaN
# 21          40                                               -2.7    NaN
# 22          30                                               -2.6    NaN
# 23          20                                               -2.2    NaN
# 24          10                                                 -2    NaN
# 25           0                                               -1.7    NaN

# %% [markdown]
# Pandas subsetting during imports: we'll read in the snow temp data and meta data separately then transpose, duplicate and combine the data

# %%
# grab the snow temperature data
dfdata = pd.read_csv('https://drive.google.com/uc?export=download&id=1DufHRYtWqxQUFrfqdFx1FViFbaTCkmAV', header = 13)
dfdata
# Out:
#      Hs  Temperature  Notes
# 0   110         -4.4    NaN
# 1   100         -3.5    NaN
# 2    90         -3.2    NaN
# 3    80         -3.1    NaN
# 4    70         -3.1    NaN
# 5    60         -3.0    NaN
# 6    50         -2.8    NaN
# 7    40         -2.7    NaN
# 8    30         -2.6    NaN
# 9    20         -2.2    NaN
# 10   10         -2.0    NaN
# 11    0         -1.7    NaN

# %%
# grab the metadata only
dfmeta = df.head(12)
dfmeta
# Out:
#              0                                                  1    2
# 0    Location:                                        County Line  NaN
# 1        Type:                                               Open  NaN
# 2     Easting:                                             756905  NaN
# 3    Northing:                                            4324353  NaN
# 4    Surveyor:                                            J. Lund  NaN
# 5        Time:                                       3/12/20 9:58  NaN
# 6   Time Type:                                                 AM  NaN
# 7    Air Temp:                                               -2.8  NaN
# 8          Hs:                                                111  NaN
# 9      Ground:               Rough ground, no info on vegetation.  NaN
# 10      Notes:                            Temperature 9:58-10:10.  NaN
# 11         Wx:  Calm, mostly cloudy, but sun still shining (th...  NaN

# %%
# transpose the metadata to columns
dftranspose = dfmeta.transpose().head(2)
dftranspose
# Out:
#             0      1         2          3          4             5   \
# 0    Location:  Type:  Easting:  Northing:  Surveyor:         Time:
# 1  County Line   Open    756905    4324353    J. Lund  3/12/20 9:58
#
#            6          7    8                                     9   \
# 0  Time Type:  Air Temp:  Hs:                               Ground:
# 1          AM       -2.8  111  Rough ground, no info on vegetation.
#
#                         10                                                 11
# 0                   Notes:                                                Wx:
# 1  Temperature 9:58-10:10.  Calm, mostly cloudy, but sun still shining (th...

# %%
# grab column names from the first row
newheader = dftranspose.iloc[0]
newheader
# Out:
# 0      Location:
# 1          Type:
# 2       Easting:
# 3      Northing:
# 4      Surveyor:
# 5          Time:
# 6     Time Type:
# 7      Air Temp:
# 8            Hs:
# 9        Ground:
# 10        Notes:
# 11           Wx:
# Name: 0, dtype: object

# %%
# remove the column names row
dftranspose = dftranspose[1:]
dftranspose
# Out:
#             0     1       2        3        4             5   6     7    8   \
# 1  County Line  Open  756905  4324353  J. Lund  3/12/20 9:58  AM  -2.8  111
#
#                                      9                        10  \
# 1  Rough ground, no info on vegetation.  Temperature 9:58-10:10.
#
#                                                   11
# 1  Calm, mostly cloudy, but sun still shining (th...

# %%
# add column names to transposed metadata
dftranspose.columns = newheader
dftranspose
# Out:
# 0    Location: Type: Easting: Northing: Surveyor:         Time: Time Type:  \
# 1  County Line  Open   756905   4324353   J. Lund  3/12/20 9:58         AM
#
# 0 Air Temp:  Hs:                               Ground:  \
# 1      -2.8  111  Rough ground, no info on vegetation.
#
# 0                   Notes:                                                Wx:
# 1  Temperature 9:58-10:10.  Calm, mostly cloudy, but sun still shining (th...

# %%
# duplicate rows of metadata to length of snow pit temperature profile
dfdup = dftranspose.reindex(dftranspose.index.repeat(len(dfdata))).reset_index(drop=True)
dfdup
# Out:
# 0     Location: Type: Easting: Northing: Surveyor:         Time: Time Type:  \
# 0   County Line  Open   756905   4324353   J. Lund  3/12/20 9:58         AM
# 1   County Line  Open   756905   4324353   J. Lund  3/12/20 9:58         AM
# 2   County Line  Open   756905   4324353   J. Lund  3/12/20 9:58         AM
# 3   County Line  Open   756905   4324353   J. Lund  3/12/20 9:58         AM
# 4   County Line  Open   756905   4324353   J. Lund  3/12/20 9:58         AM
# 5   County Line  Open   756905   4324353   J. Lund  3/12/20 9:58         AM
# 6   County Line  Open   756905   4324353   J. Lund  3/12/20 9:58         AM
# 7   County Line  Open   756905   4324353   J. Lund  3/12/20 9:58         AM
# 8   County Line  Open   756905   4324353   J. Lund  3/12/20 9:58         AM
# 9   County Line  Open   756905   4324353   J. Lund  3/12/20 9:58         AM
# 10  County Line  Open   756905   4324353   J. Lund  3/12/20 9:58         AM
# 11  County Line  Open   756905   4324353   J. Lund  3/12/20 9:58         AM
#
# 0  Air Temp:  Hs:                               Ground:  \
# 0       -2.8  111  Rough ground, no info on vegetation.
# 1       -2.8  111  Rough ground, no info on vegetation.
# 2       -2.8  111  Rough ground, no info on vegetation.
# 3       -2.8  111  Rough ground, no info on vegetation.
# 4       -2.8  111  Rough ground, no info on vegetation.
# 5       -2.8  111  Rough ground, no info on vegetation.
# 6       -2.8  111  Rough ground, no info on vegetation.
# 7       -2.8  111  Rough ground, no info on vegetation.
# 8       -2.8  111  Rough ground, no info on vegetation.
# 9       -2.8  111  Rough ground, no info on vegetation.
# 10      -2.8  111  Rough ground, no info on vegetation.
# 11      -2.8  111  Rough ground, no info on vegetation.
#
# 0                    Notes:                                                Wx:
# 0   Temperature 9:58-10:10.  Calm, mostly cloudy, but sun still shining (th...
# 1   Temperature 9:58-10:10.  Calm, mostly cloudy, but sun still shining (th...
# 2   Temperature 9:58-10:10.  Calm, mostly cloudy, but sun still shining (th...
# 3   Temperature 9:58-10:10.  Calm, mostly cloudy, but sun still shining (th...
# 4   Temperature 9:58-10:10.  Calm, mostly cloudy, but sun still shining (th...
# 5   Temperature 9:58-10:10.  Calm, mostly cloudy, but sun still shining (th...
# 6   Temperature 9:58-10:10.  Calm, mostly cloudy, but sun still shining (th...
# 7   Temperature 9:58-10:10.  Calm, mostly cloudy, but sun still shining (th...
# 8   Temperature 9:58-10:10.  Calm, mostly cloudy, but sun still shining (th...
# 9   Temperature 9:58-10:10.  Calm, mostly cloudy, but sun still shining (th...
# 10  Temperature 9:58-10:10.  Calm, mostly cloudy, but sun still shining (th...
# 11  Temperature 9:58-10:10.  Calm, mostly cloudy, but sun still shining (th...

# %%
# merge dfdata with dfdup to make a complete df of snow profile temps
dfmerged = pd.concat([dfdup, dfdata], axis = 1)
del dfmerged['Hs:'] # remove the total HS measurement column
dfmerged
# Out:
#       Location: Type: Easting: Northing: Surveyor:         Time: Time Type:  \
# 0   County Line  Open   756905   4324353   J. Lund  3/12/20 9:58         AM
# 1   County Line  Open   756905   4324353   J. Lund  3/12/20 9:58         AM
# 2   County Line  Open   756905   4324353   J. Lund  3/12/20 9:58         AM
# 3   County Line  Open   756905   4324353   J. Lund  3/12/20 9:58         AM
# 4   County Line  Open   756905   4324353   J. Lund  3/12/20 9:58         AM
# 5   County Line  Open   756905   4324353   J. Lund  3/12/20 9:58         AM
# 6   County Line  Open   756905   4324353   J. Lund  3/12/20 9:58         AM
# 7   County Line  Open   756905   4324353   J. Lund  3/12/20 9:58         AM
# 8   County Line  Open   756905   4324353   J. Lund  3/12/20 9:58         AM
# 9   County Line  Open   756905   4324353   J. Lund  3/12/20 9:58         AM
# 10  County Line  Open   756905   4324353   J. Lund  3/12/20 9:58         AM
# 11  County Line  Open   756905   4324353   J. Lund  3/12/20 9:58         AM
#
#    Air Temp:                               Ground:                   Notes:  \
# 0       -2.8  Rough ground, no info on vegetation.  Temperature 9:58-10:10.
# 1       -2.8  Rough ground, no info on vegetation.  Temperature 9:58-10:10.
# 2       -2.8  Rough ground, no info on vegetation.  Temperature 9:58-10:10.
# 3       -2.8  Rough ground, no info on vegetation.  Temperature 9:58-10:10.
# 4       -2.8  Rough ground, no info on vegetation.  Temperature 9:58-10:10.
# 5       -2.8  Rough ground, no info on vegetation.  Temperature 9:58-10:10.
# 6       -2.8  Rough ground, no info on vegetation.  Temperature 9:58-10:10.
# 7       -2.8  Rough ground, no info on vegetation.  Temperature 9:58-10:10.
# 8       -2.8  Rough ground, no info on vegetation.  Temperature 9:58-10:10.
# 9       -2.8  Rough ground, no info on vegetation.  Temperature 9:58-10:10.
# 10      -2.8  Rough ground, no info on vegetation.  Temperature 9:58-10:10.
# 11      -2.8  Rough ground, no info on vegetation.  Temperature 9:58-10:10.
#
#                                                   Wx:   Hs  Temperature  Notes
# 0   Calm, mostly cloudy, but sun still shining (th...  110         -4.4    NaN
# 1   Calm, mostly cloudy, but sun still shining (th...  100         -3.5    NaN
# 2   Calm, mostly cloudy, but sun still shining (th...   90         -3.2    NaN
# 3   Calm, mostly cloudy, but sun still shining (th...   80         -3.1    NaN
# 4   Calm, mostly cloudy, but sun still shining (th...   70         -3.1    NaN
# 5   Calm, mostly cloudy, but sun still shining (th...   60         -3.0    NaN
# 6   Calm, mostly cloudy, but sun still shining (th...   50         -2.8    NaN
# 7   Calm, mostly cloudy, but sun still shining (th...   40         -2.7    NaN
# 8   Calm, mostly cloudy, but sun still shining (th...   30         -2.6    NaN
# 9   Calm, mostly cloudy, but sun still shining (th...   20         -2.2    NaN
# 10  Calm, mostly cloudy, but sun still shining (th...   10         -2.0    NaN
# 11  Calm, mostly cloudy, but sun still shining (th...    0         -1.7    NaN

# %%
# create snow pit location geometry
import geopandas 
gdf = geopandas.GeoDataFrame(
    dfmerged, geometry=geopandas.points_from_xy(dfmerged['Easting:'], dfmerged['Northing:']))

# add lat.lon data
import utm
def utm_to_latlon(coords, zone_number, zone_letter):
    easting = coords[0]
    northing = coords[1]
    return utm.to_latlon(easting, northing, zone_number, zone_letter)

# Using nested list comprehension
gdf ["lat_lon_tuple"] = [[utm_to_latlon(xy, 13, "N") for xy in tuple(geom.coords)] for geom in gdf.geometry]

gdf
# Out:
#       Location: Type: Easting: Northing: Surveyor:         Time: Time Type:  \
# 0   County Line  Open   756905   4324353   J. Lund  3/12/20 9:58         AM
# 1   County Line  Open   756905   4324353   J. Lund  3/12/20 9:58         AM
# 2   County Line  Open   756905   4324353   J. Lund  3/12/20 9:58         AM
# 3   County Line  Open   756905   4324353   J. Lund  3/12/20 9:58         AM
# 4   County Line  Open   756905   4324353   J. Lund  3/12/20 9:58         AM
# 5   County Line  Open   756905   4324353   J. Lund  3/12/20 9:58         AM
# 6   County Line  Open   756905   4324353   J. Lund  3/12/20 9:58         AM
# 7   County Line  Open   756905   4324353   J. Lund  3/12/20 9:58         AM
# 8   County Line  Open   756905   4324353   J. Lund  3/12/20 9:58         AM
# 9   County Line  Open   756905   4324353   J. Lund  3/12/20 9:58         AM
# 10  County Line  Open   756905   4324353   J. Lund  3/12/20 9:58         AM
# 11  County Line  Open   756905   4324353   J. Lund  3/12/20 9:58         AM
#
#    Air Temp:                               Ground:                   Notes:  \
# 0       -2.8  Rough ground, no info on vegetation.  Temperature 9:58-10:10.
# 1       -2.8  Rough ground, no info on vegetation.  Temperature 9:58-10:10.
# 2       -2.8  Rough ground, no info on vegetation.  Temperature 9:58-10:10.
# 3       -2.8  Rough ground, no info on vegetation.  Temperature 9:58-10:10.
# 4       -2.8  Rough ground, no info on vegetation.  Temperature 9:58-10:10.
# 5       -2.8  Rough ground, no info on vegetation.  Temperature 9:58-10:10.
# 6       -2.8  Rough ground, no info on vegetation.  Temperature 9:58-10:10.
# 7       -2.8  Rough ground, no info on vegetation.  Temperature 9:58-10:10.
# 8       -2.8  Rough ground, no info on vegetation.  Temperature 9:58-10:10.
# 9       -2.8  Rough ground, no info on vegetation.  Temperature 9:58-10:10.
# 10      -2.8  Rough ground, no info on vegetation.  Temperature 9:58-10:10.
# 11      -2.8  Rough ground, no info on vegetation.  Temperature 9:58-10:10.
#
#                                                   Wx:   Hs  Temperature  \
# 0   Calm, mostly cloudy, but sun still shining (th...  110         -4.4
# 1   Calm, mostly cloudy, but sun still shining (th...  100         -3.5
# 2   Calm, mostly cloudy, but sun still shining (th...   90         -3.2
# 3   Calm, mostly cloudy, but sun still shining (th...   80         -3.1
# 4   Calm, mostly cloudy, but sun still shining (th...   70         -3.1
# 5   Calm, mostly cloudy, but sun still shining (th...   60         -3.0
# 6   Calm, mostly cloudy, but sun still shining (th...   50         -2.8
# 7   Calm, mostly cloudy, but sun still shining (th...   40         -2.7
# 8   Calm, mostly cloudy, but sun still shining (th...   30         -2.6
# 9   Calm, mostly cloudy, but sun still shining (th...   20         -2.2
# 10  Calm, mostly cloudy, but sun still shining (th...   10         -2.0
# 11  Calm, mostly cloudy, but sun still shining (th...    0         -1.7
#
#     Notes                        geometry  \
# 0     NaN  POINT (756905.000 4324353.000)
# 1     NaN  POINT (756905.000 4324353.000)
# 2     NaN  POINT (756905.000 4324353.000)
# 3     NaN  POINT (756905.000 4324353.000)
# 4     NaN  POINT (756905.000 4324353.000)
# 5     NaN  POINT (756905.000 4324353.000)
# 6     NaN  POINT (756905.000 4324353.000)
# 7     NaN  POINT (756905.000 4324353.000)
# 8     NaN  POINT (756905.000 4324353.000)
# 9     NaN  POINT (756905.000 4324353.000)
# 10    NaN  POINT (756905.000 4324353.000)
# 11    NaN  POINT (756905.000 4324353.000)
#
#                                  lat_lon_tuple
# 0   [(39.03049699624331, -102.03214985021661)]
# 1   [(39.03049699624331, -102.03214985021661)]
# 2   [(39.03049699624331, -102.03214985021661)]
# 3   [(39.03049699624331, -102.03214985021661)]
# 4   [(39.03049699624331, -102.03214985021661)]
# 5   [(39.03049699624331, -102.03214985021661)]
# 6   [(39.03049699624331, -102.03214985021661)]
# 7   [(39.03049699624331, -102.03214985021661)]
# 8   [(39.03049699624331, -102.03214985021661)]
# 9   [(39.03049699624331, -102.03214985021661)]
# 10  [(39.03049699624331, -102.03214985021661)]
# 11  [(39.03049699624331, -102.03214985021661)]

# %% [markdown]
# Set new column names and reorder to align with SnowEx database column headers

# %%
# grab the database column names for LayerData (in correct order)
db_colnames = ["site_name", "date", "time_created", "time_updated", "id", "doi", "date_accessed", "instrument", "type", "units", "...", "geom", "time", "depth", "site_id", 
               "bottom_depth", "comments", "sample_a", "sample_b", "sample_c", "value"]
db_colnames
# Out:
# ['site_name',
#  'date',
#  'time_created',
#  'time_updated',
#  'id',
#  'doi',
#  'date_accessed',
#  'instrument',
#  'type',
#  'units',
#  '...',
#  'geom',
#  'time',
#  'depth',
#  'site_id',
#  'bottom_depth',
#  'comments',
#  'sample_a',
#  'sample_b',
#  'sample_c',
#  'value']

# %%
# reorder dfmerged to match database order and add blank columns to fill
dfreorder = pd.DataFrame(columns = db_colnames)
dfreorder
# Out:
# Empty DataFrame
# Columns: [site_name, date, time_created, time_updated, id, doi, date_accessed, instrument, type, units, ..., geom, time, depth, site_id, bottom_depth, comments, sample_a, sample_b, sample_c, value]
# Index: []
#
# [0 rows x 21 columns]

# %%
# add Jewel's pit data into appropriate columns - probably a cleaner way to do this, but I'm too new to Py...
dfreorder['geom'] = gdf['geometry']
dfreorder['depth'] = dfmerged['Hs']
dfreorder['value'] = dfmerged['Temperature']
dfreorder['site_id'] = dfmerged['Location:']
dfreorder['type'] = 'temperature'
dfreorder['site_name'] = 'Grand Mesa'
dfreorder['time_updated'] = 'None'
dfreorder['instrument'] = 'None'
dfreorder['units'] = 'None'
dfreorder
# Out:
#      site_name date time_created time_updated   id  doi date_accessed  \
# 0   Grand Mesa  NaN          NaN         None  NaN  NaN           NaN
# 1   Grand Mesa  NaN          NaN         None  NaN  NaN           NaN
# 2   Grand Mesa  NaN          NaN         None  NaN  NaN           NaN
# 3   Grand Mesa  NaN          NaN         None  NaN  NaN           NaN
# 4   Grand Mesa  NaN          NaN         None  NaN  NaN           NaN
# 5   Grand Mesa  NaN          NaN         None  NaN  NaN           NaN
# 6   Grand Mesa  NaN          NaN         None  NaN  NaN           NaN
# 7   Grand Mesa  NaN          NaN         None  NaN  NaN           NaN
# 8   Grand Mesa  NaN          NaN         None  NaN  NaN           NaN
# 9   Grand Mesa  NaN          NaN         None  NaN  NaN           NaN
# 10  Grand Mesa  NaN          NaN         None  NaN  NaN           NaN
# 11  Grand Mesa  NaN          NaN         None  NaN  NaN           NaN
#
#    instrument         type units  ...                            geom time  \
# 0        None  temperature  None  ...  POINT (756905.000 4324353.000)  NaN
# 1        None  temperature  None  ...  POINT (756905.000 4324353.000)  NaN
# 2        None  temperature  None  ...  POINT (756905.000 4324353.000)  NaN
# 3        None  temperature  None  ...  POINT (756905.000 4324353.000)  NaN
# 4        None  temperature  None  ...  POINT (756905.000 4324353.000)  NaN
# 5        None  temperature  None  ...  POINT (756905.000 4324353.000)  NaN
# 6        None  temperature  None  ...  POINT (756905.000 4324353.000)  NaN
# 7        None  temperature  None  ...  POINT (756905.000 4324353.000)  NaN
# 8        None  temperature  None  ...  POINT (756905.000 4324353.000)  NaN
# 9        None  temperature  None  ...  POINT (756905.000 4324353.000)  NaN
# 10       None  temperature  None  ...  POINT (756905.000 4324353.000)  NaN
# 11       None  temperature  None  ...  POINT (756905.000 4324353.000)  NaN
#
#    depth      site_id bottom_depth comments sample_a sample_b sample_c value
# 0    110  County Line          NaN      NaN      NaN      NaN      NaN  -4.4
# 1    100  County Line          NaN      NaN      NaN      NaN      NaN  -3.5
# 2     90  County Line          NaN      NaN      NaN      NaN      NaN  -3.2
# 3     80  County Line          NaN      NaN      NaN      NaN      NaN  -3.1
# 4     70  County Line          NaN      NaN      NaN      NaN      NaN  -3.1
# 5     60  County Line          NaN      NaN      NaN      NaN      NaN  -3.0
# 6     50  County Line          NaN      NaN      NaN      NaN      NaN  -2.8
# 7     40  County Line          NaN      NaN      NaN      NaN      NaN  -2.7
# 8     30  County Line          NaN      NaN      NaN      NaN      NaN  -2.6
# 9     20  County Line          NaN      NaN      NaN      NaN      NaN  -2.2
# 10    10  County Line          NaN      NaN      NaN      NaN      NaN  -2.0
# 11     0  County Line          NaN      NaN      NaN      NaN      NaN  -1.7
#
# [12 rows x 21 columns]

# %%
# split date/time to separate columns
date_time = dfmerged['Time:'].str.split(expand=True)
dfreorder['date'] = date_time[0]
dfreorder['time'] = date_time[1]
dfreorder
# Out:
#      site_name     date time_created time_updated   id  doi date_accessed  \
# 0   Grand Mesa  3/12/20          NaN         None  NaN  NaN           NaN
# 1   Grand Mesa  3/12/20          NaN         None  NaN  NaN           NaN
# 2   Grand Mesa  3/12/20          NaN         None  NaN  NaN           NaN
# 3   Grand Mesa  3/12/20          NaN         None  NaN  NaN           NaN
# 4   Grand Mesa  3/12/20          NaN         None  NaN  NaN           NaN
# 5   Grand Mesa  3/12/20          NaN         None  NaN  NaN           NaN
# 6   Grand Mesa  3/12/20          NaN         None  NaN  NaN           NaN
# 7   Grand Mesa  3/12/20          NaN         None  NaN  NaN           NaN
# 8   Grand Mesa  3/12/20          NaN         None  NaN  NaN           NaN
# 9   Grand Mesa  3/12/20          NaN         None  NaN  NaN           NaN
# 10  Grand Mesa  3/12/20          NaN         None  NaN  NaN           NaN
# 11  Grand Mesa  3/12/20          NaN         None  NaN  NaN           NaN
#
#    instrument         type units  ...                            geom  time  \
# 0        None  temperature  None  ...  POINT (756905.000 4324353.000)  9:58
# 1        None  temperature  None  ...  POINT (756905.000 4324353.000)  9:58
# 2        None  temperature  None  ...  POINT (756905.000 4324353.000)  9:58
# 3        None  temperature  None  ...  POINT (756905.000 4324353.000)  9:58
# 4        None  temperature  None  ...  POINT (756905.000 4324353.000)  9:58
# 5        None  temperature  None  ...  POINT (756905.000 4324353.000)  9:58
# 6        None  temperature  None  ...  POINT (756905.000 4324353.000)  9:58
# 7        None  temperature  None  ...  POINT (756905.000 4324353.000)  9:58
# 8        None  temperature  None  ...  POINT (756905.000 4324353.000)  9:58
# 9        None  temperature  None  ...  POINT (756905.000 4324353.000)  9:58
# 10       None  temperature  None  ...  POINT (756905.000 4324353.000)  9:58
# 11       None  temperature  None  ...  POINT (756905.000 4324353.000)  9:58
#
#    depth      site_id bottom_depth comments sample_a sample_b sample_c value
# 0    110  County Line          NaN      NaN      NaN      NaN      NaN  -4.4
# 1    100  County Line          NaN      NaN      NaN      NaN      NaN  -3.5
# 2     90  County Line          NaN      NaN      NaN      NaN      NaN  -3.2
# 3     80  County Line          NaN      NaN      NaN      NaN      NaN  -3.1
# 4     70  County Line          NaN      NaN      NaN      NaN      NaN  -3.1
# 5     60  County Line          NaN      NaN      NaN      NaN      NaN  -3.0
# 6     50  County Line          NaN      NaN      NaN      NaN      NaN  -2.8
# 7     40  County Line          NaN      NaN      NaN      NaN      NaN  -2.7
# 8     30  County Line          NaN      NaN      NaN      NaN      NaN  -2.6
# 9     20  County Line          NaN      NaN      NaN      NaN      NaN  -2.2
# 10    10  County Line          NaN      NaN      NaN      NaN      NaN  -2.0
# 11     0  County Line          NaN      NaN      NaN      NaN      NaN  -1.7
#
# [12 rows x 21 columns]

# %% [markdown]
# Creating a SiteData dataframe that conforms with SnowEx dataframe structure

# %%
# create dataframe with headers from SnowEx PointData
Sitedf = pd.DataFrame(columns = ['site_name', 'date', 'time_created', 'time_updated', 'id', 'site_id',
       'doi', 'date_accessed', 'latitude', 'longitude', 'northing', 'easting',
       'elevation', 'utm_zone', 'geom', 'time', 'slope_angle', 'aspect',
       'air_temp', 'total_depth', 'weather_description', 'precip', 'sky_cover',
       'wind', 'ground_condition', 'ground_roughness', 'ground_vegetation',
       'vegetation_height', 'tree_canopy', 'site_notes'])
Sitedf
# Out:
# Empty DataFrame
# Columns: [site_name, date, time_created, time_updated, id, site_id, doi, date_accessed, latitude, longitude, northing, easting, elevation, utm_zone, geom, time, slope_angle, aspect, air_temp, total_depth, weather_description, precip, sky_cover, wind, ground_condition, ground_roughness, ground_vegetation, vegetation_height, tree_canopy, site_notes]
# Index: []
#
# [0 rows x 30 columns]

# %%
# Fill the columns with metadata from Jewel's snow pits
Sitedf['site_name'] = 'Grand Mesa'
Sitedf['date'] = dfreorder['date'].iloc[0]
Sitedf['time_updated'] = 'None'
Sitedf['site_id'] = dfreorder['site_id'].iloc[0]
Sitedf['geom'] = dfreorder['geom'].iloc[0]
Sitedf['utm_zone'] = 12
Sitedf['time'] = dfreorder['time'].iloc[0]
Sitedf['air_temp'] = dftranspose['Air Temp:']
Sitedf['total_depth'] = dftranspose['Hs:']
Sitedf['weather_description'] = dftranspose['Wx:']
Sitedf['ground_roughness'] = dftranspose['Ground:']
Sitedf['tree_canopy'] = dftranspose['Type:']
Sitedf['site_notes'] = dftranspose['Notes:']

Sitedf
# Out:
#   site_name date time_created time_updated   id site_id  doi date_accessed  \
# 1       NaN  NaN          NaN          NaN  NaN     NaN  NaN           NaN
#
#   latitude longitude  ...                                weather_description  \
# 1      NaN       NaN  ...  Calm, mostly cloudy, but sun still shining (th...
#
#   precip sky_cover  wind ground_condition  \
# 1    NaN       NaN   NaN              NaN
#
#                        ground_roughness ground_vegetation vegetation_height  \
# 1  Rough ground, no info on vegetation.               NaN               NaN
#
#   tree_canopy               site_notes
# 1        Open  Temperature 9:58-10:10.
#
# [1 rows x 30 columns]

# %%
# grab lat/lon data by separating the column in gdf
latlon = gdf['lat_lon_tuple'].iloc[0]
LL = latlon[0]
Sitedf['latitude'] = LL[0]
Sitedf['longitude'] = LL[1]

Sitedf
# Out:
#   site_name date time_created time_updated   id site_id  doi date_accessed  \
# 1       NaN  NaN          NaN          NaN  NaN     NaN  NaN           NaN
#
#     latitude  longitude  ...  \
# 1  39.030497 -102.03215  ...
#
#                                  weather_description precip sky_cover  wind  \
# 1  Calm, mostly cloudy, but sun still shining (th...    NaN       NaN   NaN
#
#   ground_condition                      ground_roughness ground_vegetation  \
# 1              NaN  Rough ground, no info on vegetation.               NaN
#
#   vegetation_height tree_canopy               site_notes
# 1               NaN        Open  Temperature 9:58-10:10.
#
# [1 rows x 30 columns]

# %% [markdown]
# # Here we've got a LayerData dataframe and a SiteData dataframe for a single pit profile
# - We could create a PointData dataframe to comply with the SnowEx database...
# - We need to loop this script to create a massive pair of dataframes for use in our project

# %%
# LayerData dataframe
print(dfreorder.head)
# Out:
# <bound method NDFrame.head of      site_name     date time_created time_updated   id  doi date_accessed  \
# 0   Grand Mesa  3/12/20          NaN         None  NaN  NaN           NaN
# 1   Grand Mesa  3/12/20          NaN         None  NaN  NaN           NaN
# 2   Grand Mesa  3/12/20          NaN         None  NaN  NaN           NaN
# 3   Grand Mesa  3/12/20          NaN         None  NaN  NaN           NaN
# 4   Grand Mesa  3/12/20          NaN         None  NaN  NaN           NaN
# 5   Grand Mesa  3/12/20          NaN         None  NaN  NaN           NaN
# 6   Grand Mesa  3/12/20          NaN         None  NaN  NaN           NaN
# 7   Grand Mesa  3/12/20          NaN         None  NaN  NaN           NaN
# 8   Grand Mesa  3/12/20          NaN         None  NaN  NaN           NaN
# 9   Grand Mesa  3/12/20          NaN         None  NaN  NaN           NaN
# 10  Grand Mesa  3/12/20          NaN         None  NaN  NaN           NaN
# 11  Grand Mesa  3/12/20          NaN         None  NaN  NaN           NaN
#
#    instrument         type units  ...                            geom  time  \
# 0        None  temperature  None  ...  POINT (756905.000 4324353.000)  9:58
# 1        None  temperature  None  ...  POINT (756905.000 4324353.000)  9:58
# 2        None  temperature  None  ...  POINT (756905.000 4324353.000)  9:58
# 3        None  temperature  None  ...  POINT (756905.000 4324353.000)  9:58
# 4        None  temperature  None  ...  POINT (756905.000 4324353.000)  9:58
# 5        None  temperature  None  ...  POINT (756905.000 4324353.000)  9:58
# 6        None  temperature  None  ...  POINT (756905.000 4324353.000)  9:58
# 7        None  temperature  None  ...  POINT (756905.000 4324353.000)  9:58
# 8        None  temperature  None  ...  POINT (756905.000 4324353.000)  9:58
# 9        None  temperature  None  ...  POINT (756905.000 4324353.000)  9:58
# 10       None  temperature  None  ...  POINT (756905.000 4324353.000)  9:58
# 11       None  temperature  None  ...  POINT (756905.000 4324353.000)  9:58
#
#    depth      site_id bottom_depth comments sample_a sample_b sample_c value
# 0    110  County Line          NaN      NaN      NaN      NaN      NaN  -4.4
# 1    100  County Line          NaN      NaN      NaN      NaN      NaN  -3.5
# 2     90  County Line          NaN      NaN      NaN      NaN      NaN  -3.2
# 3     80  County Line          NaN      NaN      NaN      NaN      NaN  -3.1
# 4     70  County Line          NaN      NaN      NaN      NaN      NaN  -3.1
# 5     60  County Line          NaN      NaN      NaN      NaN      NaN  -3.0
# 6     50  County Line          NaN      NaN      NaN      NaN      NaN  -2.8
# 7     40  County Line          NaN      NaN      NaN      NaN      NaN  -2.7
# 8     30  County Line          NaN      NaN      NaN      NaN      NaN  -2.6
# 9     20  County Line          NaN      NaN      NaN      NaN      NaN  -2.2
# 10    10  County Line          NaN      NaN      NaN      NaN      NaN  -2.0
# 11     0  County Line          NaN      NaN      NaN      NaN      NaN  -1.7
#
# [12 rows x 21 columns]>

# %%
# SiteData dataframe
print(Sitedf.head)
# Out:
# <bound method NDFrame.head of   site_name date time_created time_updated   id site_id  doi date_accessed  \
# 1       NaN  NaN          NaN          NaN  NaN     NaN  NaN           NaN
#
#     latitude  longitude  ...  \
# 1  39.030497 -102.03215  ...
#
#                                  weather_description precip sky_cover  wind  \
# 1  Calm, mostly cloudy, but sun still shining (th...    NaN       NaN   NaN
#
#   ground_condition                      ground_roughness ground_vegetation  \
# 1              NaN  Rough ground, no info on vegetation.               NaN
#
#   vegetation_height tree_canopy               site_notes
# 1               NaN        Open  Temperature 9:58-10:10.
#
# [1 rows x 30 columns]>
